# %%
import pymc3 as pm
import numpy as np
import matplotlib.pyplot as plt

# %%
fileName = 'datosT1P2.txt'
data = np.loadtxt(fileName)

fig = plt.figure(0,(16,3))
plt.plot(data[:,0],data[:,1])
plt.title('Data')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.grid()
plt.show(fig)

# %%
nData = data.shape[0]
nTrain = int(np.ceil(0.75*nData))

print('Total data: %i\nTrain data: %i\nTest data : %i' %(nData, nTrain, nData-nTrain))

train_set = data[0:nTrain,:]
test_set  = data[nTrain:,:]

fig = plt.figure(0,(16,3))
plt.plot(train_set[:,0],train_set[:,1],'.-')
plt.plot(test_set[:,0],test_set[:,1],'.-')
plt.title('Data')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend(('Train set', 'Test set'))
plt.grid()
plt.show(fig)

print(train_set[0,0],train_set[-1,0])
print(train_set[0,1],train_set[-1,1])
# Out:
# Total data: 144
# Train data: 108
# Test data : 36
# 0.0 107.0
# 112.0 336.0

# %% [markdown]
# # Model
#
# This model have the following structure:
#
# $$
# y = f_{\theta} + \eta
# $$
#
# where, $\eta\sim N(0,\sigma_{\eta}^2)$ and $\theta$ are the parameters for $f(\cdot)$. Then, the probability associated to $(x,y)$ is given by:
#
# $$
# p(y|f(\cdot), x) = \frac{1}{\sqrt{2\pi\sigma_{\eta}^2}}\exp{\left(-\frac{(y-f(x))^2}{2\sigma_{\eta}^2}\right)}
# $$
#
# In this case, the model for $f(\cdot)$ is a polynomial. Then, $\theta = [\theta_0, \theta_1, ..., \theta_n]$ where:
#
# $$
# f(x) = \theta_0 + \theta_1x + ...+ \theta_n x^n
# $$

# %%
import theano.tensor as tt

grade = 3

k = np.linspace(0,grade,grade+1)
X = train_set[:,0][:,np.newaxis]

X_aux = X.repeat(grade+1,axis=1)
X_aux = np.power(X_aux,k)

print('X shape: %sx%s' % X_aux.shape)

Y = train_set[:,1]
print('Y shape: %s' % Y.shape)


basic_model = pm.Model()

with basic_model:
    # Priors for unknown model parameters
    theta0 = pm.Normal('theta0', mu=112.0, sd=100)
    theta1 = pm.Normal('theta1', mu=2, sd=100)
    theta2 = pm.Normal('theta2', mu=1, sd=100)
    # theta3 = pm.Normal('theta3', mu=0, sd=100)
    # sigma = pm.HalfNormal('sigma', sd=10)
    sigma = pm.HalfNormal('sigma_y', sd=20)

    # Expected value of outcome
    mu_obs = theta0+theta1*X+theta2*np.power(X,2)#+theta3*np.power(X,3)
    # mu_obs = np.sum(np.dot(theta,X_aux),axis = 1)
    print('mu_obs shape: %s'% mu_obs.shape)
        
    # Model
    Y_obs = pm.Normal('Y_obs', mu=mu_obs, sd=sigma, observed=Y)
    
    ## sample using MEtropolis
    # step = pm.Metropolis()
    # trace = pm.sample(10000, step)

map_estimate = pm.find_MAP(model=basic_model)

print(map_estimate)
# Out:
# X shape: 108x4
# Y shape: 108
# mu_obs shape: Shape.0
# ...
#          Current function value: 68418.791951
#          Iterations: 45
#          Function evaluations: 117
#          Gradient evaluations: 103
# {'theta0': array(230.8340839736629), 'theta1': array(0.0023842180965642115), 'theta2': array(-1.848432916289564e-05), 'sigma_y_log_': array(4.443983711205708)}

# %%
# theta = [float(map_estimate['theta1']),float(map_estimate['theta0'])]
theta = [float(map_estimate['theta2']), float(map_estimate['theta1']),float(map_estimate['theta0'])]
# theta = [float(map_estimate['theta3']), float(map_estimate['theta2']), float(map_estimate['theta1']),float(map_estimate['theta0'])]

X_test = test_set[:,0]
Y_test = test_set[:,1]

Y_train_hat = np.polyval(theta,X)
Y_hat = np.polyval(theta,X_test)

fig = plt.figure(0,(16,3))
plt.plot(X,Y,'.-')
plt.plot(X,Y_train_hat,'.-')
plt.plot(X_test,Y_test,'.-')
plt.plot(X_test,Y_hat ,'.-')
plt.title('Data')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend(('Train set', 'Predicted over train', 'Test set', 'Predicted over test'))
plt.grid()
plt.show(fig)

# %%
import mle

def fpol(a,x):
    return np.polyval(a,x)

X = train_set[:,0]

print('X shape: %sx%s' % X_aux.shape)

Y = train_set[:,1]
print('Y shape: %s' % Y.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-7609975d1fc4> in <module>()
# ----> 1 import mle
#       2
#       3 def fpol(a,x):
#       4     return np.polyval(a,x)
#       5
#
# ModuleNotFoundError: No module named 'mle'

# %%
theta_sin = [float(map_estimate['theta1']), float(map_estimate['theta2']), float(map_estimate['theta3']),float(map_estimate['theta4'])]

X_test = test_set[:,0]
Y_test = test_set[:,1]

Y_train_hat = np.polyval(theta,X)+ float(map_estimate['theta1'])*np.sin(float(map_estimate['theta2'])*X + float(map_estimate['theta3']))*np.exp(float(map_estimate['theta4'])*X)
Y_hat = np.polyval(theta,X_test) + float(map_estimate['theta1'])*np.sin(float(map_estimate['theta2'])*X_test + float(map_estimate['theta3']))*np.exp(float(map_estimate['theta4'])*X_test)

fig = plt.figure(0,(16,3))
plt.plot(X,Y,'.-')
plt.plot(X,Y_train_hat,'.-')
plt.plot(X_test,Y_test,'.-')
plt.plot(X_test,Y_hat ,'.-')
plt.title('Data')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend(('Train set', 'Predicted over train', 'Test set', 'Predicted over test'))
plt.grid()
plt.show(fig)

# %%
def f_pol_sin(x,a,b):
    return np.polyval(a,x)+ b[0]*np.sin(b[1]*x+b[2])*np.exp(b[3])

X = train_set[:,0]

print('X shape: %sx%s' % X_aux.shape)

Y = train_set[:,1]
print('Y shape: %s' % Y.shape)


basic_model_final = pm.Model()

with basic_model_final:
    # Priors for unknown model parameters
    theta1 = pm.Normal('theta1', mu=-10, sd=100)
    theta2 = pm.Normal('theta2', mu=-1, sd=100)
    theta3 = pm.Normal('theta3', mu=1, sd=100)
    theta4 = pm.Normal('theta4', mu=0.1, sd=1)
    # sigma = pm.HalfNormal('sigma', sd=10)
    sigma = pm.HalfNormal('sigma_y', sd=100)

    # Expected value of outcome
    mu_obs = f_pol_sin(X,theta,theta_sin) + theta1*np.sin(theta2*X+theta3)*np.exp(theta4*X)
    # mu_obs = np.sum(np.dot(theta,X_aux),axis = 1)
    print('mu_obs shape: %s'% mu_obs.shape)
        
    # Model
    Y_obs = pm.Normal('Y_obs', mu=mu_obs, sd=sigma, observed=Y)
    
    ## sample using Metropolis
    # step = pm.Metropolis()
    # trace = pm.sample(10000, step)

map_estimate = pm.find_MAP(model=basic_model_final)

print(map_estimate)
# Out:
# X shape: 108x4
# Y shape: 108
# mu_obs shape: Shape.0
# Optimization terminated successfully.
#          Current function value: 531.479989
#          Iterations: 136
#          Function evaluations: 211
#          Gradient evaluations: 210
# {'theta1': array(-10.872148791859145), 'theta2': array(-6.799439478442892), 'theta3': array(0.9259996975166677), 'theta4': array(0.01890754016950368), 'sigma_y_log_': array(3.3301804597643807)}

# %%
theta_sin_sin = [float(map_estimate['theta1']), float(map_estimate['theta2']), float(map_estimate['theta3']),float(map_estimate['theta4'])]

X_test = test_set[:,0]
Y_test = test_set[:,1]

Y_train_hat = f_pol_sin(X,theta,theta_sin)+ float(map_estimate['theta1'])*np.sin(float(map_estimate['theta2'])*X + float(map_estimate['theta3']))*np.exp(float(map_estimate['theta4'])*X)
Y_hat = f_pol_sin(X_test,theta,theta_sin) + float(map_estimate['theta1'])*np.sin(float(map_estimate['theta2'])*X_test + float(map_estimate['theta3']))*np.exp(float(map_estimate['theta4'])*X_test)

fig = plt.figure(0,(16,3))
plt.plot(X[1:],Y[1:],'.-')
plt.plot(X[1:],Y_train_hat[1:],'.-')
plt.plot(X_test,Y_test,'.-')
plt.plot(X_test,Y_hat ,'.-')
plt.title('Data')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend(('Train set', 'Predicted over train', 'Test set', 'Predicted over test'))
plt.grid()
plt.show(fig)
